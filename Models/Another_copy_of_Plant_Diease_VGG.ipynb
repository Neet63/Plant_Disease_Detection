# %%
# !pip install -q kaggle

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']="/content"

# %%
# !kaggle datasets download -d vipoooool/new-plant-diseases-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/vipoooool/new-plant-diseases-dataset
# License(s): copyright-authors
# Downloading new-plant-diseases-dataset.zip to /content
#  99% 2.68G/2.70G [00:12<00:00, 239MB/s]
# 100% 2.70G/2.70G [00:12<00:00, 225MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/new-plant-diseases-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import matplotlib.pyplot as plt
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import skimage
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import warnings
warnings.filterwarnings('ignore')

# %%
# The path of the dataset
train_data_path = '/content/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train'
valid_data_path = '/content/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid'

categories = os.listdir(train_data_path)
print(f'The Number Of categories are : {len(categories)} Category')
# Out:
# The Number Of categories are : 38 Category

# %%
cat_freq = {}
for cat in categories:
    cat_freq[cat] = len(os.listdir(train_data_path + "/" + cat))

cat_freq_df = pd.DataFrame.from_dict(cat_freq, orient='index', columns=['Frequencies'])

cat_freq_df.reset_index(inplace=True)
cat_freq_df.columns = ['Categories', 'Frequencies']
cat_freq_df
# Out:
#                                            Categories  Frequencies
# 0                                  Apple___Apple_scab         2016
# 1            Orange___Haunglongbing_(Citrus_greening)         2010
# 2   Corn_(maize)___Cercospora_leaf_spot Gray_leaf_...         1642
# 3                         Tomato___Septoria_leaf_spot         1745
# 4                       Pepper,_bell___Bacterial_spot         1913
# 5                                   Soybean___healthy         2022
# 6                                Tomato___Target_Spot         1827
# 7                              Corn_(maize)___healthy         1859
# 8                                     Apple___healthy         2008
# 9                        Tomato___Tomato_mosaic_virus         1790
# 10                                  Grape___Black_rot         1888
# 11           Cherry_(including_sour)___Powdery_mildew         1683
# 12                              Tomato___Early_blight         1920
# 13         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)         1722
# 14                                   Tomato___healthy         1926
# 15                               Potato___Late_blight         1939
# 16                                    Peach___healthy         1728
# 17                  Cherry_(including_sour)___healthy         1826
# 18                              Potato___Early_blight         1939
# 19                       Grape___Esca_(Black_Measles)         1920
# 20                           Apple___Cedar_apple_rust         1760
# 21                Corn_(maize)___Northern_Leaf_Blight         1908
# 22                               Tomato___Late_blight         1851
# 23                            Tomato___Bacterial_spot         1702
# 24                             Peach___Bacterial_spot         1838
# 25                                Blueberry___healthy         1816
# 26                                  Apple___Black_rot         1987
# 27                                Raspberry___healthy         1781
# 28                           Strawberry___Leaf_scorch         1774
# 29             Tomato___Tomato_Yellow_Leaf_Curl_Virus         1961
# 30                                 Tomato___Leaf_Mold         1882
# 31                             Pepper,_bell___healthy         1988
# 32                                   Potato___healthy         1824
# 33      Tomato___Spider_mites Two-spotted_spider_mite         1741
# 34                               Strawberry___healthy         1824
# 35                                    Grape___healthy         1692
# 36                        Corn_(maize)___Common_rust_         1907
# 37                            Squash___Powdery_mildew         1736

# %%
cat_freq_df.describe()
# Out:
#        Frequencies
# count    38.000000
# mean   1849.868421
# std     105.724315
# min    1642.000000
# 25%    1763.500000
# 50%    1844.500000
# 75%    1924.500000
# max    2022.000000

# %%
plt.figure(figsize=(15, 10))
plt.bar(cat_freq_df['Categories'], cat_freq_df['Frequencies'])
plt.xlabel('Categories')
plt.ylabel('Frequencies')
plt.title('Frequency of Items')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
fruits_veg = []
for cat in categories:
    fruits_veg.append(cat.split('___')[0])
unique_fruites_veg = list(np.unique(fruits_veg))

print(f'The represents {len(unique_fruites_veg)} Different types of Fruits and Vegetables as follows : ')
unique_fruites_veg
# Out:
# The represents 14 Different types of Fruits and Vegetables as follows :
# ['Apple',
#  'Blueberry',
#  'Cherry_(including_sour)',
#  'Corn_(maize)',
#  'Grape',
#  'Orange',
#  'Peach',
#  'Pepper,_bell',
#  'Potato',
#  'Raspberry',
#  'Soybean',
#  'Squash',
#  'Strawberry',
#  'Tomato']

# %%
veg_fruite_cat = {}
for i in unique_fruites_veg:
    num = 0
    for j in categories:
        if i in j:
            num +=1
    veg_fruite_cat[i] = num
veg_fruite_cat
# Out:
# {'Apple': 4,
#  'Blueberry': 1,
#  'Cherry_(including_sour)': 2,
#  'Corn_(maize)': 4,
#  'Grape': 4,
#  'Orange': 1,
#  'Peach': 2,
#  'Pepper,_bell': 2,
#  'Potato': 3,
#  'Raspberry': 1,
#  'Soybean': 1,
#  'Squash': 1,
#  'Strawberry': 2,
#  'Tomato': 10}

# %%
# Define paths for the sampled dataset
sampled_train_dir = 'Dataset\\Sampled\\train\\'
sampled_valid_dir = 'Dataset\\Sampled\\valid\\'

# %%
# Create directories if they don't exist
os.makedirs(sampled_train_dir, exist_ok=True)
os.makedirs(sampled_valid_dir, exist_ok=True)

# %%
def sample_dataset(data_dir, output_dir, sample_size=0.1):
    """
    Sample a subset of the dataset.

    Parameters:
    - data_dir: The directory containing the original dataset.
    - output_dir: The directory where the sampled dataset will be stored.
    - sample_size: The fraction of the dataset to sample.
    """
    categories = os.listdir(data_dir)

    for category in categories:
        # Create category directory in the sampled output directory
        os.makedirs(os.path.join(output_dir, category), exist_ok=True)

        # Get all images in the current category
        images = os.listdir(os.path.join(data_dir, category))

        # Sample a fraction of the images
        sampled_images = np.random.choice(images, int(len(images) * sample_size), replace=False)

        # Copy the sampled images to the output directory
        for image in sampled_images:
            src = os.path.join(data_dir, category, image)
            dst = os.path.join(output_dir, category, image)
            shutil.copy(src, dst)

# %%
# Sample 10-20% of the dataset
sample_percentage = 0.15 # Adjust between 0.1 and 0.2 for 10-20%
sample_dataset(train_data_path, sampled_train_dir, sample_percentage)
sample_dataset(valid_data_path, sampled_valid_dir, sample_percentage)

# %%
# Set up ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Create training data generator
train_generator = train_datagen.flow_from_directory(
    sampled_train_dir,
    target_size=(256, 256),  # Resize images to match model input
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

# Create validation data generator
validation_generator = validation_datagen.flow_from_directory(
    sampled_valid_dir,
    target_size=(256, 256),  # Resize images to match model input
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 10529 images belonging to 38 classes.
# Found 2618 images belonging to 38 classes.

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
# Load the MobileNet model with pre-trained weights on ImageNet, excluding the top layers


base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add a global average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)

# Add a fully-connected layer with 1024 units and ReLU activation
x = Dense(1024, activation='relu')(x)

# Add a final softmax layer with the number of classes (38 in your case)
predictions = Dense(train_generator.num_classes, activation='softmax')(x)

# Define the final model
model = Model(inputs=base_model.input, outputs=predictions)

# Freeze the base model layers for transfer learning
for layer in base_model.layers:
    layer.trainable = False

# Compile the model

# %%
# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d_2  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 1024)              525312
#
#  dense_5 (Dense)             (None, 38)                38950
#
# =================================================================
# Total params: 15278950 (58.28 MB)
# Trainable params: 564262 (2.15 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# Define callbacks
checkpoint_path = "best_vgg16_model.h5"  # Path where the best model will be saved

checkpoint = ModelCheckpoint(
    checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_accuracy', patience=3, mode='max', verbose=1, restore_best_weights=True
)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=2, verbose=1, min_lr=0.0001
)

# %%
# Train the model
history = model.fit(
    train_generator,  # Your training data generator
    epochs=10,  # Adjust the number of epochs as needed
    validation_data=validation_generator,  # Your validation data generator
    callbacks=[checkpoint, early_stopping, reduce_lr]  # Add the callbacks here
)
# Out:
# Epoch 1/10
# 330/330 [==============================] - ETA: 0s - loss: 1.8276 - accuracy: 0.5460 - precision: 0.9283 - recall: 0.2116
# Epoch 1: val_accuracy improved from -inf to 0.75325, saving model to best_vgg16_model.h5
# 330/330 [==============================] - 294s 888ms/step - loss: 1.8276 - accuracy: 0.5460 - precision: 0.9283 - recall: 0.2116 - val_loss: 0.9570 - val_accuracy: 0.7532 - val_precision: 0.9205 - val_recall: 0.5218 - lr: 0.0010
# Epoch 2/10
# 330/330 [==============================] - ETA: 0s - loss: 0.7585 - accuracy: 0.7812 - precision: 0.9143 - recall: 0.6262
# Epoch 2: val_accuracy improved from 0.75325 to 0.81131, saving model to best_vgg16_model.h5
# 330/330 [==============================] - 293s 887ms/step - loss: 0.7585 - accuracy: 0.7812 - precision: 0.9143 - recall: 0.6262 - val_loss: 0.6332 - val_accuracy: 0.8113 - val_precision: 0.9191 - val_recall: 0.6986 - lr: 0.0010
# Epoch 3/10
# 330/330 [==============================] - ETA: 0s - loss: 0.5765 - accuracy: 0.8277 - precision: 0.9129 - recall: 0.7340
# Epoch 3: val_accuracy improved from 0.81131 to 0.84683, saving model to best_vgg16_model.h5
# 330/330 [==============================] - 296s 896ms/step - loss: 0.5765 - accuracy: 0.8277 - precision: 0.9129 - recall: 0.7340 - val_loss: 0.5128 - val_accuracy: 0.8468 - val_precision: 0.9239 - val_recall: 0.7701 - lr: 0.0010
# Epoch 4/10
# 330/330 [==============================] - ETA: 0s - loss: 0.4507 - accuracy: 0.8621 - precision: 0.9230 - recall: 0.7991
# Epoch 4: val_accuracy improved from 0.84683 to 0.85676, saving model to best_vgg16_model.h5
# 330/330 [==============================] - 292s 886ms/step - loss: 0.4507 - accuracy: 0.8621 - precision: 0.9230 - recall: 0.7991 - val_loss: 0.4657 - val_accuracy: 0.8568 - val_precision: 0.9250 - val_recall: 0.7911 - lr: 0.0010
# Epoch 5/10
# 330/330 [==============================] - ETA: 0s - loss: 0.3747 - accuracy: 0.8844 - precision: 0.9345 - recall: 0.8339
# Epoch 5: val_accuracy improved from 0.85676 to 0.87395, saving model to best_vgg16_model.h5
# 330/330 [==============================] - 296s 897ms/step - loss: 0.3747 - accuracy: 0.8844 - precision: 0.9345 - recall: 0.8339 - val_loss: 0.4096 - val_accuracy: 0.8739 - val_precision: 0.9270 - val_recall: 0.8289 - lr: 0.0010
# Epoch 6/10
# 330/330 [==============================] - ETA: 0s - loss: 0.3218 - accuracy: 0.9004 - precision: 0.9388 - recall: 0.8593
# Epoch 6: val_accuracy did not improve from 0.87395
# 330/330 [==============================] - 295s 893ms/step - loss: 0.3218 - accuracy: 0.9004 - precision: 0.9388 - recall: 0.8593 - val_loss: 0.4177 - val_accuracy: 0.8617 - val_precision: 0.9056 - val_recall: 0.8205 - lr: 0.0010
# Epoch 7/10
# 330/330 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.9050 - precision: 0.9427 - recall: 0.8720
# Epoch 7: val_accuracy improved from 0.87395 to 0.87548, saving model to best_vgg16_model.h5
# 330/330 [==============================] - 293s 887ms/step - loss: 0.2960 - accuracy: 0.9050 - precision: 0.9427 - recall: 0.8720 - val_loss: 0.3662 - val_accuracy: 0.8755 - val_precision: 0.9224 - val_recall: 0.8491 - lr: 0.0010
# Epoch 8/10
# 330/330 [==============================] - ETA: 0s - loss: 0.2628 - accuracy: 0.9135 - precision: 0.9450 - recall: 0.8873
# Epoch 8: val_accuracy improved from 0.87548 to 0.89228, saving model to best_vgg16_model.h5
# 330/330 [==============================] - 293s 888ms/step - loss: 0.2628 - accuracy: 0.9135 - precision: 0.9450 - recall: 0.8873 - val_loss: 0.3541 - val_accuracy: 0.8923 - val_precision: 0.9246 - val_recall: 0.8663 - lr: 0.0010
# Epoch 9/10
# 330/330 [==============================] - ETA: 0s - loss: 0.2460 - accuracy: 0.9216 - precision: 0.9495 - recall: 0.8956
# Epoch 9: val_accuracy improved from 0.89228 to 0.89687, saving model to best_vgg16_model.h5
# 330/330 [==============================] - 295s 893ms/step - loss: 0.2460 - accuracy: 0.9216 - precision: 0.9495 - recall: 0.8956 - val_loss: 0.3309 - val_accuracy: 0.8969 - val_precision: 0.9271 - val_recall: 0.8690 - lr: 0.0010
# Epoch 10/10
# 330/330 [==============================] - ETA: 0s - loss: 0.2342 - accuracy: 0.9264 - precision: 0.9482 - recall: 0.9034
# Epoch 10: val_accuracy improved from 0.89687 to 0.90985, saving model to best_vgg16_model.h5
# 330/330 [==============================] - 295s 895ms/step - loss: 0.2342 - accuracy: 0.9264 - precision: 0.9482 - recall: 0.9034 - val_loss: 0.2841 - val_accuracy: 0.9099 - val_precision: 0.9340 - val_recall: 0.8862 - lr: 0.0010

# %%
best_model = tf.keras.models.load_model('best_vgg16_model.h5')

# %%
loss, accuracy,precison,recall = best_model.evaluate(validation_generator)
print(f'Validation Loss: {loss}')
print(f'Validation Accuracy: {accuracy}')
print(f'Validation Precision: {precison}')
print(f'Validation Recall: {recall}')
# Out:
# 82/82 [==============================] - 58s 699ms/step - loss: 0.2841 - accuracy: 0.9099 - precision: 0.9340 - recall: 0.8862
# Validation Loss: 0.2841182053089142
# Validation Accuracy: 0.9098548293113708
# Validation Precision: 0.933977484703064
# Validation Recall: 0.8861726522445679

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('VGG16 Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
  plt.figure(figsize=(10, 6))
  plt.plot(history.history['loss'], label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('VGG16 Model Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(loc='upper right')
  plt.grid(True)
  plt.show()

# %%
from sklearn.metrics import confusion_matrix

Y_pred = best_model.predict(validation_generator)
y_pred = np.argmax(Y_pred, axis=1)
y_true = validation_generator.classes

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix for VGG16')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 82/82 [==============================] - 58s 703ms/step

# %%
from sklearn.metrics import f1_score, roc_curve, auc, r2_score
import numpy as np
import matplotlib.pyplot as plt

# %%
validation_generator.reset()

y_pred = best_model.predict(validation_generator, verbose=1)
y_pred_class = np.argmax(y_pred, axis=1)

y_true = validation_generator.classes
class_indices = validation_generator.class_indices

inverse_class_indices = {v: k for k, v in class_indices.items()}
# Out:
# 82/82 [==============================] - 58s 709ms/step

# %%
f1 = f1_score(y_true, y_pred_class, average='macro')
print(f"Macro F1 Score: {f1}")
# Out:
# Macro F1 Score: 0.9086991190970667

# %%
y_true_one_hot = tf.keras.utils.to_categorical(y_true, num_classes=len(class_indices))

r2 = r2_score(y_true_one_hot, y_pred)
print(f"R2 Score: {r2}")
# Out:
# R2 Score: 0.862263023853302

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle
import matplotlib.cm as cm

# Binarize the output labels for ROC curve calculation
y_true_bin = label_binarize(y_true, classes=list(range(len(class_indices))))
n_classes = y_true_bin.shape[1]

# Calculate ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_true_bin.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Generate a colormap with 38 different colors
colors = cm.get_cmap('tab20', n_classes)

# Plotting all ROC curves
plt.figure(figsize=(12, 8))

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], color=colors(i), lw=2,
             label='Class {0} (area = {1:0.2f})'.format(inverse_class_indices[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Of VGG16')
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5), fontsize='small')  # Adjusted font size and position
plt.show()
